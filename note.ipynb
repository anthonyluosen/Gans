# %% [markdown]
# We train D to maximize the probability of assigning the correct label to both training examples and samples from G.<br>
# As stated above, the discriminator seeks to maximize the average of the log probability of real images and the log of the inverse probability for fake images.
#
# discriminator: maximize log D(x) + log(1 – D(G(z)))<br>
# The generator seeks to minimize the log of the inverse probability predicted by the discriminator for fake images. This has the effect of encouraging the generator to generate samples that have a low probability of being fake.
#
# generator: minimize log(1 – D(G(z)))<br>
# ''Here the generator learns to generate samples that have a low probability of being fake.''
#
# — Are GANs Created Equal? A Large-Scale Study, 2018.

# %% [markdown]
# In practice, [the loss function] may not provide sufficient gradient for G to learn well. Early in learning, when G is poor, D can reject samples with high confidence because they are clearly different from the training data.
#
# — Generative Adversarial Networks, 2014.

# %% [markdown]
# ℓ(x,y)=L={l
# 1
# ​
#  ,…,l
# N
# ​
#  }
# ⊤
#  ,l
# n
# ​
#  =−w
# n
# ​
#  [y
# n
# ​
#  ⋅logx
# n
# ​
#  +(1−y
# n
# ​
#  )⋅log(1−x
# n
# ​
#  )],

# %% [markdown]
# Discriminator adversarial loss always went to zero, while the Generator loss was really high. I immediately concluded that one network had not enough “capacity” to keep up with the other one:<br>
# It is well know that making the training of the discriminator more difficult is beneficial for the overall stability. One of the most known methods to increase the complexity of the discriminator training is adding noise to both the real and synthetic data

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# Read-through: Wasserstein GAN
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
